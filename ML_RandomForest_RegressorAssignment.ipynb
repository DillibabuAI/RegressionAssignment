# %%
#getting library files
import pandas as pd

# %%
#stroing the client data into dataset variable
dataset = pd.read_csv("insurance_pre.csv")

# %%
#displaying the dataset
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
#display number of rows, columns
dataset.shape
# Out:
# (1338, 6)

# %%
#removing dummies from dataset
dataset = pd.get_dummies(dataset, drop_first = True)

# %%
#display dataset post removing dummies
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
#display column names of dataset
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
#assign the input data to independent variable
independent = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
#assign the output data to dependent variable
dependent = dataset[['charges']]

# %%
#display input data shape and column values
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0     False        True
# 1      18  33.770         1      True       False
# 2      28  33.000         3      True       False
# 3      33  22.705         0      True       False
# 4      32  28.880         0      True       False
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3      True       False
# 1334   18  31.920         0     False       False
# 1335   18  36.850         0     False       False
# 1336   21  25.800         0     False       False
# 1337   61  29.070         0     False        True
#
# [1338 rows x 5 columns]

# %%
#displaying the output data values
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
#here we are doing model_selection and splitting the training, test set data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(independent, dependent, test_size = 0.30, random_state = 0)

# %%
#display the training data set values
X_train
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 1163   18  28.215         0     False       False
# 196    39  32.800         0     False       False
# 438    52  46.750         5     False       False
# 183    44  26.410         0     False       False
# 1298   33  27.455         2      True       False
# ...   ...     ...       ...       ...         ...
# 763    27  26.030         0      True       False
# 835    42  35.970         2      True       False
# 1216   40  25.080         0      True       False
# 559    19  35.530         0      True       False
# 684    33  18.500         1     False       False
#
# [936 rows x 5 columns]

# %%
#display x_test data
X_test
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 578    52  30.200         1      True       False
# 610    47  29.370         1     False       False
# 569    48  40.565         2      True        True
# 1034   61  38.380         0      True       False
# 198    51  18.050         0     False       False
# ...   ...     ...       ...       ...         ...
# 1261   28  37.100         1      True       False
# 494    21  25.700         4      True        True
# 97     55  38.280         0      True       False
# 418    64  39.160         1      True       False
# 920    62  25.000         0     False       False
#
# [402 rows x 5 columns]

# %%
#display the shape of training data
X_train.shape
# Out:
# (936, 5)

# %%
#display the shape of test set data
X_test.shape
# Out:
# (402, 5)

# %%
#from sklearn ensemble module we are importing RandomForestRegressor and assiging the method to regressor variable
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(criterion = 'poisson', n_estimators = 50)
regressor.fit(X_train, y_train)
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor(criterion='poisson', n_estimators=50)

# %%
#predicting the value and assigning to y_pred variable
y_pred = regressor.predict(X_test)

# %%
#importing evaluation metrics and calculate r_score
from sklearn.metrics import r2_score
r_score = r2_score(y_test, y_pred)

# %%
#display the r_score value
r_score
# Out:
# 0.8533367817108061

# %%
#import pickle library for deployment phase
import pickle

# %%
#assign the saving model file name to filename variable
filename = "finalized-model_RandomForestRegressor_Poisson50.sav"
#using pickle dump method write the file on disk
pickle.dump(regressor, open(filename, 'wb'))

# %%
#loading the saved model to loaded_variable.
loaded_model = pickle.load(open(filename, 'rb'))

# %%
#here we are pedicting the value like we want and assigning to result variable.
result = loaded_model.predict([[21, 432.34, 2, True, False]])
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
#display the result array value
result
# Out:
# array([4628.787222])
